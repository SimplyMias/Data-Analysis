# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Numpy:", np.__version__)
print("Pandas:", pd.__version__)
print("Ready!")
# Out:
# Numpy: 2.0.2
# Pandas: 2.2.2
# Ready!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Tab Completion
#
# While entering expressions in
# the shell, pressing the Tab key will search the namespace for any variables (objects,
# functions, etc.) matching the characters you have typed so far and show the results in
# a convenient drop-down menu:

# %% [markdown]
# ##Introspection
#
# Using a question mark (?) before or after a variable will display some general infor‐
# mation about the object:

# %%
b = [1,2,3]
#b?

# %% [markdown]
# ##Python Language Basics
#
# **Identation not braces**
# Python uses whitespaces (tabs or spaces) to structr code instead of using braces

# %% [markdown]
# Python statements also do not need to be terminated by
# semicolons. Semicolons can be used, however, to separate multiple statements on a
# single line:

# %%
a = 5; b = 6; c = 7
# Putting multiple statements on one line is generally discouraged in Python as it can make code less readable

# %% [markdown]
# **Everything is an object**
#
# In python everything like strings, number, data structures and so on exists in the python interpretor in its own box which is reffered to as a Python Object
#
# Each object has a associated type (e.g., integer, string or function) and internl data

# %% [markdown]
# **Comments**
#
# comments are text in between code which are ignored by the interpretor.

# %%
results = []
for line in file_handle:
  # keep the empty lines for now
  # if len(line) == 0
  #    continue
  results.append(line.replace("foo","bar"))

print("Reached this line") # Simple status report

# %% [markdown]
# **Function and Object method calls**
#
# we call functions using parantheses with zero or more arguments optionally

# %%
# assigining the returned value to a variable
#result = f(x, y,z)
#g()

# %% [markdown]
# Almost Every object in python has attached functions, known as methods, that have access to the object's internal contents
#
# you can call them using the followin syntax
#
# obj.some_method(x,y,z)

# %%
# Functions can take both positional and keyword arguments
result = f(a, b, c, d= 5, e="foo")

# %% [markdown]
# **Variables and Argument Passing**

# %% [markdown]
# In python when we are assigning a value a variable. we are creating a refrence to the obect shown on the righthand side pf the equals sign = (we call it assignment operator)

# %%
# Considering list of integers
a = [1,2,3]
# assigning a to a new variable b
b = a

# %%
b # Output: [1,2,3]
# Out:
# [1, 2, 3]

# %% [markdown]
# In some languages, the assignment if b will cause the data [1, 2, 3] to be copied. In
# Python, a and b actually now refer to the same object

# %%
# demostrating
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Two refrences for the same object

# %% [markdown]
# **Dynamic refrences, strong types**

# %% [markdown]
# A variable can refer to different type of object simply by doing an assignment

# %%
# Example
a = 5
print(type(a))

a = "foo"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# variables are names for ojects within a particular namespace; the type information is stored in the object itself
#
# some observer might hasitly conclude that Python is not a "typed language". This is not True; consider this example

# %%
"5" + 5 # In Python such implicits casts are not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3650/4107985378.py in <cell line: 0>()
# ----> 1 "5" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# In this regard we say Python is an strongly typed language,
#
# which means that every object has a specific type (or class ) and implicit conversions will occur only in certain permitted circumstances such as

# %%
a = 4.5
b = 2

print(f"a is {type(a)}, b is {type(b)}")
a/b # here b is integer still b is converted to float for the division operation
# Out:
# a is <class 'float'>, b is <class 'int'>
# 2.25

# %% [markdown]
# Knowing the type of an object is important
#
# we can check that an object is  an instance of particular type using the isinstance function  which will return True or False accordingly

# %%
a = 5
isinstance(a, int)
# oytput: True

# isinstance can accept a tuple of types
a = 5; b = 4.5
isinstance(a, (int, float))
isinstance(b,(int,float))
# Out:
# True

# %% [markdown]
# **Attributes and Methods**
#
# Objects in Python have both attributes and meethods
#
# Attruibutes = Other python object stored inside the object
#
# Methods = Functions associated with an object that can ave access to the object's internal data
#
# both of them are accessed via syntax:
#
# obj.attribute_name

# %%
#Example
a = "foo"
a.capitalize()

# Attributes and methods can also be accessed by name via the getattr function:
getattr(a, "split")
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %% [markdown]
# **Binary Operators and Comparisons**
#
# Most of the binary math operations and comparisons use familiar mathematical
# syntax used in other programming languages:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
5-7
#Output: -2

12+21.5
# Output: 33.5

5 <= 2
# Output: False
# Out:
# -2

# %% [markdown]
# is keyword = Used to  check if two variables refer to the same object
#
# is not keyword = Used to check that two objects are not same

# %%
a = [1,2,3]

b = a

c = list(a)

# %% [markdown]
# Using the list function to create a list will create a complet new list which is distinct from a
#
# Comparing with **is** is not the same as the "==" operator

# %%
a is b
# True
a is not c
# True
# Out:
# True

# %% [markdown]
# The common  use of is and is not is to check if a variable is None

# %%
# since there is only one instance of none
a =  None
a is None # True
# Out:
# True

# %% [markdown]
# **Mutable and Immutable Objects**
#
# Mutables means the Values or data the object contains can be modified such as: lists, dictionaries, Numpy arrays and most user defined types

# %%
a_list = ["foo", 2, [4,5]]
a_list[2] = (3,4)
a_list
# Out:
# ['foo', 2, (3, 4)]

# %% [markdown]
# Immutable Objects are those whose internal data can not be changed or objects which cannot be modified such as Strings and Tuples

# %%
a_tuple = (3,5,(4,5))
# a_tuple[1] = "four" # This will through error as tuples are immutable

# %% [markdown]
# ## Scalar Types
#
# Python has small set of built-in types for handling different type of data
#
# scalar types are a specific category of data types. They are defined as types that represent a "single value"—such as an integer, a floating-point number, a string, or a Boolean (True or False).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Numeric Types**
#
# Python type for numbers are int and float
#
# int can store arbitrarily large numbers
#
# float can store floating point numbers

# %%
ival = 12884798273487237498
ival * 6
# Out:
# 77308789640923424988

# %%
fval = 7.243
fval2 = 6.7e-5 # scintific method can be used to represent floats also

# %%
3/2 # result of integer devision will be floating point number

# to get C like integer division use // operator which will drop the floating part
3//2
# Out:
# 1

# %% [markdown]
# **Strings**
#
#
# String are the collection of characters
#
# string literal can be written using single or a double quote
#
# python string type is str
#
# strings are immutable means we cannot modify characters of the string

# %%
# One way of writing string
a = 'one way of writing'
b = "another way of writing"

# %%
# For multiline strings with line breaks we can use triple qoutes either ''' or """"

c = """
This is a longer string that
spans multiple lines
"""

print(c)
print(c.count("\n"))
# Out:
# This is a longer string that
# spans multiple lines
#
# 3

# %%
# to modify a string, we have to use a function or method that creates a new string, such as the string replace method:\
a = "this is a string"
b = a.replace("string", "longer string")

# after this operation variable a is unmodified
b
# Out:
# 'this is a longer string'

# %%
# many python objects can be converted into string using str() function
a = 5.6
s = str(a)
print(s)
type(s)
# Out:
# 5.6
# str

# %% [markdown]
# Strings are sequence of unicode characters therefore can be treated like other sequences such as lists tuples

# %%
s = "python"
list(s)
s[:3] # slicing
# Out:
# 'pyt'

# %% [markdown]
# The backslash character \ is an escape character meaning that it is used to specify special characters like newline \n or Unicode characters
#
# To write a strinng literal with
# backslashes, you need to escape them:

# %%
s = '3\\4' #output: 3/4
print(s)
# Out:
# 3\4

# %% [markdown]
# If you have a string with a lot of backslashes and no special characters, you might find
# this a bit annoying. Fortunately you can preface the leading quote of the string with r,
# which means that the characters should be interpreted as is:

# %%
s = r"this\has\no\special\characters"
print(s)
# the r stands for raw
# Out:
# this\has\no\special\characters

# %% [markdown]
# Adding two strings together concatenates them and produces a new string

# %%
a = "This is the first half "
b = "and this is the second half"
a + b
# Out:
# 'This is the first half and this is the second half'

# %% [markdown]
# String objects have a format method that can be used to substitute formatted arguments into the string producing a new string

# %%
template = "{0:.2f} {1:s} are worth US${2:d}"
# In this string
# {0:.2f} means format the first argument a floating point number with two decimal places
# {1:s} means to format the second argument as a string
# {2:d} means to format the third argument as an exact integer

# To substitue arguments for these format parameters we pass a sequence of arguments to the format method
template.format(88.46, "Argentine Pesos", 1)
# Out:
# '88.46 Argentine Pesos are worth US$1'

# %% [markdown]
# In python 3.6 this formatting is reduced to f-strings  (short for formatted string literals)
#
# To create an f string
#
# write the character f immediately preceding a string literal within the string enclose python expressions in curly braces to substitute the value of the expression into the formatted string

# %%
amount = 10
rate = 88.46
currency = "Pesos"
result = f"{amount} {currency} is worth US${amount/rate:.2f}"
print(result)
# Out:
# 10 Pesos is worth US$0.11

# %% [markdown]
# **Bytes and Unicodes**

# %%
val = "español"

val_utf8 = val.encode("utf-8")
val_utf8

type(val_utf8)
# Out:
# bytes

# %% [markdown]
# Assuming you know the Unicode encoding of a bytes object, you can go back using
# the decode method:

# %%
val_utf8.decode("utf-8")
# Out:
# 'español'

# %% [markdown]
# While it is now preferable to use UTF-8 for any encoding, for historical reasons you
# may encounter data in any number of different encodings:

# %%
val_latin = val.encode("latin1")
val_latin
# Out:
# b'espa\xf1ol'

# %%
val_utf16 = val.encode("utf-16")
val_utf16
# Out:
# b'\xff\xfee\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'

# %%
val.encode("utf-16le")
# Out:
# b'e\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'

# %% [markdown]
# **Booleans**
#
# The two boolean values in Python are written as True and False
#
# Comparisons and other conditional expressions evaluate to either True or False
#
# Boolean values are combined with the *and* and *or* keywords

# %%
True and True #o/p True
True or False #o/p True

# %% [markdown]
# When converted to numbers, False becomes 0 and True becomes 1:

# %%
int(True) #o/p 1
int(False) #o/p 0
# Out:
# 1

# %% [markdown]
# The keyword not flips a Boolean value from True to False or vice versa:

# %%
a = True
b = False

not a # o/p False
not b # o/p True
# Out:
# True

# %% [markdown]
# **Type casting**
#
# The str, int, float, bool are also functions that can be used to cast values to those types:

# %%
s = "3.14159"
fval = float(s)
type(fval)
#output: float
int(fval)
#output: 3
bool(fval)
#output: True
bool(0)
#output: False

# Note that most nonzero values when cast to bool become True.
# Out:
# True

# %% [markdown]
# **None**
#
# None is the Python null value type

# %%
a  = None
a is None # Output True

b = 5
b is not None # Output True
# Out:
# True

# %%
# None is also a common default value for function arguments

def add_and_maybe_multiply(a,b,c=None):
  return a + b

  if a is not None:
    result = result * c

  return result
